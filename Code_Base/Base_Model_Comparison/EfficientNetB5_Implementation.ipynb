# %%
import os
import shutil
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input, Flatten, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.applications import EfficientNetB5
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from itertools import cycle

# %%
gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

# %%
# Define paths
base_dir = '/home/user/GPU_CSE/Kirti/Dataset_for_Code_Development/Dataset_for_5_classes_by_Sir/EfficientNetB5'
dataset_dir = '/home/user/GPU_CSE/Kirti/Dataset_for_Code_Development/Dataset_for_5_classes_by_Sir/clean_train_partition'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %%
# Parameters
img_height, img_width = 224, 224 # EfficientNetB1 requires images of size 224x224
batch_size = 32
num_classes = len(next(os.walk(dataset_dir))[1])  # number of class folders
train_ratio = 0.7
validation_ratio = 0.15
test_ratio = 0.15

# %%
# Function to create train, validation, and test splits
def create_splits():
    try:
        if not os.path.exists(train_dir):
            os.makedirs(train_dir)
        if not os.path.exists(validation_dir):
            os.makedirs(validation_dir)
        if not os.path.exists(test_dir):
            os.makedirs(test_dir)
    
        for class_name in os.listdir(dataset_dir):        
            train_class_path = os.path.join(train_dir, class_name)        
            if not os.path.exists(train_class_path):
                os.makedirs(train_class_path)        
            
            test_class_path = os.path.join(test_dir, class_name)        
            if not os.path.exists(test_class_path):
                os.makedirs(test_class_path)        
    
            validation_class_dir = os.path.join(validation_dir, class_name)       
            if not os.path.exists(validation_class_dir):
                os.makedirs(validation_class_dir)        
        
        for class_name in os.listdir(dataset_dir):        
            class_path = os.path.join(dataset_dir, class_name)
            
            if os.path.isdir(class_path):
                images = os.listdir(class_path)
                random.shuffle(images)
                train_split = int(train_ratio * len(images))
                validation_split = int(validation_ratio * len(images))
                
                train_images = images[:train_split]
                validation_images = images[train_split:train_split + validation_split]
                test_images = images[train_split + validation_split:]
    
                for image in train_images:
                    shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name, image))
                for image in validation_images:
                    shutil.copy(os.path.join(class_path, image), os.path.join(validation_dir, class_name, image))
                for image in test_images:
                    shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name, image))
    except Exception as err:
        print("Error:", str(err))

# %%
# Split the dataset
create_splits()

# %%
# Data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    brightness_range=(0.8, 1.2)
)

# %%
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical'
)

validation_generator = val_datagen.flow_from_directory(
    validation_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1083 images belonging to 5 classes.
# Found 230 images belonging to 5 classes.
# Found 239 images belonging to 5 classes.

# %%
# Load the EfficientNetB5 model pretrained on ImageNet
base_model = EfficientNetB5(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_1.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Out:
# 2024-08-08 13:23:28.572692: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 940 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:86:00.0, compute capability: 8.6
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 263s 2us/step

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 2024-08-08 13:28:12.259520: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8905
# 2024-08-08 13:28:12.588986: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-08-08 13:28:12.681259: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa8362eb3a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-08-08 13:28:12.681288: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-08-08 13:28:12.686696: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-08 13:28:12.836689: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 33/33 [==============================] - ETA: 0s - loss: 1.7107 - accuracy: 0.2008
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 33/33 [==============================] - 33s 553ms/step - loss: 1.7107 - accuracy: 0.2008 - val_loss: 1.6172 - val_accuracy: 0.2054
# Epoch 2/50
# 33/33 [==============================] - 15s 463ms/step - loss: 1.6484 - accuracy: 0.2084 - val_loss: 1.6123 - val_accuracy: 0.1920
# Epoch 3/50
# 33/33 [==============================] - 15s 464ms/step - loss: 1.6398 - accuracy: 0.2131 - val_loss: 1.6117 - val_accuracy: 0.1964
# Epoch 4/50
# 33/33 [==============================] - 15s 462ms/step - loss: 1.6177 - accuracy: 0.2236 - val_loss: 1.6089 - val_accuracy: 0.2143
# Epoch 5/50
# 33/33 [==============================] - 14s 422ms/step - loss: 1.6270 - accuracy: 0.2103 - val_loss: 1.6090 - val_accuracy: 0.1830
# Epoch 6/50
# 33/33 [==============================] - 14s 428ms/step - loss: 1.6275 - accuracy: 0.1970 - val_loss: 1.6101 - val_accuracy: 0.1473
# Epoch 7/50
# 33/33 [==============================] - 16s 472ms/step - loss: 1.6226 - accuracy: 0.2017 - val_loss: 1.6086 - val_accuracy: 0.2277
# Epoch 8/50
# 33/33 [==============================] - 15s 463ms/step - loss: 1.6041 - accuracy: 0.2388 - val_loss: 1.6075 - val_accuracy: 0.2232
# Epoch 9/50
# 33/33 [==============================] - 15s 464ms/step - loss: 1.6237 - accuracy: 0.2341 - val_loss: 1.6048 - val_accuracy: 0.2188
# Epoch 10/50
# 33/33 [==============================] - 14s 430ms/step - loss: 1.6373 - accuracy: 0.2169 - val_loss: 1.6080 - val_accuracy: 0.2009
# Epoch 11/50
# 33/33 [==============================] - 14s 429ms/step - loss: 1.6286 - accuracy: 0.2103 - val_loss: 1.6079 - val_accuracy: 0.2232
# Epoch 12/50
# 33/33 [==============================] - 15s 458ms/step - loss: 1.6087 - accuracy: 0.2483 - val_loss: 1.5990 - val_accuracy: 0.2366
# Epoch 13/50
# 33/33 [==============================] - 14s 427ms/step - loss: 1.6305 - accuracy: 0.2027 - val_loss: 1.6146 - val_accuracy: 0.1875
# Epoch 14/50
# 33/33 [==============================] - 14s 429ms/step - loss: 1.6168 - accuracy: 0.2131 - val_loss: 1.6147 - val_accuracy: 0.1920
# Epoch 15/50
# 33/33 [==============================] - 14s 434ms/step - loss: 1.6174 - accuracy: 0.2141 - val_loss: 1.6002 - val_accuracy: 0.2009
# Epoch 16/50
# 33/33 [==============================] - 15s 465ms/step - loss: 1.6119 - accuracy: 0.2226 - val_loss: 1.5953 - val_accuracy: 0.2411
# Epoch 17/50
# 33/33 [==============================] - 14s 424ms/step - loss: 1.6144 - accuracy: 0.2322 - val_loss: 1.6024 - val_accuracy: 0.1964
# Epoch 18/50
# 33/33 [==============================] - 14s 428ms/step - loss: 1.6108 - accuracy: 0.2141 - val_loss: 1.6130 - val_accuracy: 0.2188
# Epoch 19/50
# 33/33 [==============================] - 14s 429ms/step - loss: 1.6194 - accuracy: 0.2226 - val_loss: 1.6074 - val_accuracy: 0.2321
# Epoch 20/50
# 33/33 [==============================] - 15s 463ms/step - loss: 1.6147 - accuracy: 0.2150 - val_loss: 1.5905 - val_accuracy: 0.2366
# Epoch 21/50
# 33/33 [==============================] - 14s 428ms/step - loss: 1.6143 - accuracy: 0.2320 - val_loss: 1.5963 - val_accuracy: 0.2500
# Epoch 22/50
# 33/33 [==============================] - 14s 421ms/step - loss: 1.6283 - accuracy: 0.2159 - val_loss: 1.6027 - val_accuracy: 0.2143
# Epoch 23/50
# 33/33 [==============================] - 14s 423ms/step - loss: 1.6338 - accuracy: 0.2055 - val_loss: 1.5949 - val_accuracy: 0.2411
# Epoch 24/50
# 33/33 [==============================] - 14s 427ms/step - loss: 1.6074 - accuracy: 0.2417 - val_loss: 1.6015 - val_accuracy: 0.2277
# Epoch 25/50
# 33/33 [==============================] - 14s 428ms/step - loss: 1.6402 - accuracy: 0.2064 - val_loss: 1.6131 - val_accuracy: 0.2500
# Epoch 26/50
# 33/33 [==============================] - 14s 432ms/step - loss: 1.6154 - accuracy: 0.2265 - val_loss: 1.6025 - val_accuracy: 0.2411
# Epoch 27/50
# 33/33 [==============================] - 14s 426ms/step - loss: 1.6030 - accuracy: 0.2312 - val_loss: 1.5959 - val_accuracy: 0.2679
# Epoch 28/50
# 33/33 [==============================] - 14s 429ms/step - loss: 1.6111 - accuracy: 0.2236 - val_loss: 1.5979 - val_accuracy: 0.2500
# Epoch 29/50
# 33/33 [==============================] - 14s 426ms/step - loss: 1.6048 - accuracy: 0.2236 - val_loss: 1.5984 - val_accuracy: 0.1830
# Epoch 30/50
# 33/33 [==============================] - 15s 450ms/step - loss: 1.6219 - accuracy: 0.2293 - val_loss: 1.6290 - val_accuracy: 0.2232

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')
# Out:
# 8/8 [==============================] - 1s 85ms/step - loss: 1.6196 - accuracy: 0.2134
# Test accuracy: 0.21

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 8/8 [==============================] - 4s 77ms/step

# %% [markdown]
# # Architecture No 2

# %%
# Load the EfficientNetB5 model pretrained on ImageNet
base_model = EfficientNetB5(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-2:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_2.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 33/33 [==============================] - ETA: 0s - loss: 1.7369 - accuracy: 0.1912
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 33/33 [==============================] - 33s 535ms/step - loss: 1.7369 - accuracy: 0.1912 - val_loss: 1.6140 - val_accuracy: 0.2009
# Epoch 2/50
# 33/33 [==============================] - 14s 423ms/step - loss: 1.6370 - accuracy: 0.2331 - val_loss: 1.6146 - val_accuracy: 0.1964
# Epoch 3/50
# 33/33 [==============================] - 15s 455ms/step - loss: 1.6466 - accuracy: 0.2169 - val_loss: 1.6131 - val_accuracy: 0.2232
# Epoch 4/50
# 33/33 [==============================] - 15s 456ms/step - loss: 1.6363 - accuracy: 0.2046 - val_loss: 1.6103 - val_accuracy: 0.2188
# Epoch 5/50
# 33/33 [==============================] - 15s 462ms/step - loss: 1.6314 - accuracy: 0.2255 - val_loss: 1.6083 - val_accuracy: 0.2545
# Epoch 6/50
# 33/33 [==============================] - 16s 471ms/step - loss: 1.6162 - accuracy: 0.2188 - val_loss: 1.6058 - val_accuracy: 0.2277
# Epoch 7/50
# 33/33 [==============================] - 15s 456ms/step - loss: 1.6402 - accuracy: 0.2236 - val_loss: 1.6043 - val_accuracy: 0.2188
# Epoch 8/50
# 33/33 [==============================] - 15s 445ms/step - loss: 1.6281 - accuracy: 0.2455 - val_loss: 1.6035 - val_accuracy: 0.2188
# Epoch 9/50
# 33/33 [==============================] - 15s 457ms/step - loss: 1.6273 - accuracy: 0.2455 - val_loss: 1.6023 - val_accuracy: 0.2277
# Epoch 10/50
# 33/33 [==============================] - 14s 417ms/step - loss: 1.6382 - accuracy: 0.2093 - val_loss: 1.6042 - val_accuracy: 0.2143
# Epoch 11/50
# 33/33 [==============================] - 14s 417ms/step - loss: 1.6192 - accuracy: 0.2255 - val_loss: 1.6053 - val_accuracy: 0.2232
# Epoch 12/50
# 33/33 [==============================] - 14s 416ms/step - loss: 1.6256 - accuracy: 0.2217 - val_loss: 1.6094 - val_accuracy: 0.2321
# Epoch 13/50
# 33/33 [==============================] - 14s 423ms/step - loss: 1.6288 - accuracy: 0.2141 - val_loss: 1.6026 - val_accuracy: 0.2188
# Epoch 14/50
# 33/33 [==============================] - 14s 413ms/step - loss: 1.6227 - accuracy: 0.2274 - val_loss: 1.6057 - val_accuracy: 0.2411
# Epoch 34/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.6292 - accuracy: 0.2255 - val_loss: 1.6038 - val_accuracy: 0.2277
# Epoch 35/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6100 - accuracy: 0.2084 - val_loss: 1.6070 - val_accuracy: 0.2188
# Epoch 36/50
# 33/33 [==============================] - 15s 448ms/step - loss: 1.6201 - accuracy: 0.2131 - val_loss: 1.5888 - val_accuracy: 0.2366
# Epoch 37/50
# 33/33 [==============================] - 15s 451ms/step - loss: 1.6292 - accuracy: 0.2322 - val_loss: 1.5886 - val_accuracy: 0.2277
# Epoch 38/50
# 33/33 [==============================] - 14s 417ms/step - loss: 1.6169 - accuracy: 0.2216 - val_loss: 1.6344 - val_accuracy: 0.2054
# Epoch 39/50
# 33/33 [==============================] - 13s 405ms/step - loss: 1.6136 - accuracy: 0.2236 - val_loss: 1.5971 - val_accuracy: 0.2411
# Epoch 40/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.6192 - accuracy: 0.1989 - val_loss: 1.5986 - val_accuracy: 0.2054
# Epoch 41/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.6153 - accuracy: 0.2331 - val_loss: 1.6363 - val_accuracy: 0.2188
# Epoch 42/50
# 33/33 [==============================] - 14s 408ms/step - loss: 1.6361 - accuracy: 0.1960 - val_loss: 1.6418 - val_accuracy: 0.1875
# Epoch 43/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.6140 - accuracy: 0.2360 - val_loss: 1.6053 - val_accuracy: 0.2143
# Epoch 44/50
# 33/33 [==============================] - 14s 413ms/step - loss: 1.6210 - accuracy: 0.2084 - val_loss: 1.6028 - val_accuracy: 0.2366
# Epoch 45/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6134 - accuracy: 0.2436 - val_loss: 1.5980 - val_accuracy: 0.2321
# Epoch 46/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.6188 - accuracy: 0.2265 - val_loss: 1.6031 - val_accuracy: 0.2366
# Epoch 47/50
# 33/33 [==============================] - 14s 427ms/step - loss: 1.6344 - accuracy: 0.2084 - val_loss: 1.5986 - val_accuracy: 0.2500

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')
# Out:
# 8/8 [==============================] - 1s 86ms/step - loss: 1.6281 - accuracy: 0.2176
# Test accuracy: 0.22

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 8/8 [==============================] - 3s 78ms/step

# %% [markdown]
# # Architecture No 4

# %%
# Load the EfficientNetB5 model pretrained on ImageNet
base_model = EfficientNetB5(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-3:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_4.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 2024-08-08 13:47:35.913550: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-08-08 13:47:47.275989: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 220.50MiB (rounded to 231211008)requested by op model_2/block2a_expand_bn/FusedBatchNormV3
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-08-08 13:47:47.276241: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-08-08 13:47:47.276277: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 458, Chunks in use: 456. 114.5KiB allocated for chunks. 114.0KiB in use in bin. 33.2KiB client-requested in use in bin.
# 2024-08-08 13:47:47.276302: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 163, Chunks in use: 163. 100.2KiB allocated for chunks. 100.2KiB in use in bin. 87.4KiB client-requested in use in bin.
# 2024-08-08 13:47:47.276325: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 264, Chunks in use: 263. 334.0KiB allocated for chunks. 332.8KiB in use in bin. 308.6KiB client-requested in use in bin.
# 2024-08-08 13:47:47.276346: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 175, Chunks in use: 170. 492.0KiB allocated for chunks. 479.2KiB in use in bin. 463.5KiB client-requested in use in bin.
# 2024-08-08 13:47:47.276366: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 315, Chunks in use: 309. 1.78MiB allocated for chunks. 1.74MiB in use in bin. 1.68MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276386: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 108, Chunks in use: 103. 1.15MiB allocated for chunks. 1.10MiB in use in bin. 1004.0KiB client-requested in use in bin.
# 2024-08-08 13:47:47.276407: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 35, Chunks in use: 30. 816.2KiB allocated for chunks. 705.0KiB in use in bin. 661.1KiB client-requested in use in bin.
# 2024-08-08 13:47:47.276427: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 52, Chunks in use: 41. 2.13MiB allocated for chunks. 1.62MiB in use in bin. 1.31MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276445: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 73, Chunks in use: 63. 6.76MiB allocated for chunks. 5.89MiB in use in bin. 5.67MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276466: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 67, Chunks in use: 60. 11.69MiB allocated for chunks. 10.43MiB in use in bin. 9.34MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276487: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 39, Chunks in use: 33. 14.02MiB allocated for chunks. 11.71MiB in use in bin. 10.59MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276508: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 79, Chunks in use: 74. 50.56MiB allocated for chunks. 46.88MiB in use in bin. 43.30MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276529: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 19, Chunks in use: 11. 26.85MiB allocated for chunks. 15.80MiB in use in bin. 15.16MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276551: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 47, Chunks in use: 43. 108.16MiB allocated for chunks. 94.69MiB in use in bin. 91.93MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276572: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 14, Chunks in use: 10. 74.09MiB allocated for chunks. 54.00MiB in use in bin. 48.12MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276593: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 12, Chunks in use: 9. 109.88MiB allocated for chunks. 76.97MiB in use in bin. 66.00MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276614: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 3, Chunks in use: 0. 68.49MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-08-08 13:47:47.276632: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-08-08 13:47:47.276649: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 1, Chunks in use: 0. 73.50MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-08-08 13:47:47.276671: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 2, Chunks in use: 1. 389.69MiB allocated for chunks. 220.50MiB in use in bin. 220.50MiB client-requested in use in bin.
# 2024-08-08 13:47:47.276687: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-08-08 13:47:47.276706: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 220.50MiB was 128.00MiB, Chunk State:
# 2024-08-08 13:47:47.276742: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 169.19MiB | Requested Size: 4B | in_use: 0 | bin_num: 19, prev:   Size: 220.50MiB | Requested Size: 220.50MiB | in_use: 1 | bin_num: -1
# 2024-08-08 13:47:47.276757: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 986251264
# 2024-08-08 13:47:47.276775: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000000 of size 1280 next 1
# 2024-08-08 13:47:47.276790: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000500 of size 256 next 2
# 2024-08-08 13:47:47.276804: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000600 of size 256 next 3
# 2024-08-08 13:47:47.276817: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000700 of size 256 next 4
# 2024-08-08 13:47:47.276830: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000800 of size 256 next 5
# 2024-08-08 13:47:47.276843: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000900 of size 256 next 6
# 2024-08-08 13:47:47.276857: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000a00 of size 256 next 7
# 2024-08-08 13:47:47.276870: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000b00 of size 256 next 8
# 2024-08-08 13:47:47.276883: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000c00 of size 256 next 9
# 2024-08-08 13:47:47.276896: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000d00 of size 256 next 894
# 2024-08-08 13:47:47.276909: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000e00 of size 256 next 918
# 2024-08-08 13:47:47.276923: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac000f00 of size 256 next 900
# 2024-08-08 13:47:47.276936: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001000 of size 256 next 15
# 2024-08-08 13:47:47.276949: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001100 of size 256 next 16
# 2024-08-08 13:47:47.276962: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001200 of size 256 next 891
# 2024-08-08 13:47:47.276976: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001300 of size 256 next 19
# 2024-08-08 13:47:47.276989: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001400 of size 256 next 17
# 2024-08-08 13:47:47.277002: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001500 of size 256 next 22
# 2024-08-08 13:47:47.277015: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001600 of size 256 next 23
# 2024-08-08 13:47:47.277029: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001700 of size 256 next 25
# 2024-08-08 13:47:47.277042: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001800 of size 256 next 24
# 2024-08-08 13:47:47.277055: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001900 of size 256 next 27
# 2024-08-08 13:47:47.277068: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001a00 of size 256 next 28
# 2024-08-08 13:47:47.277081: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001b00 of size 256 next 31
# 2024-08-08 13:47:47.277095: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001c00 of size 256 next 14
# 2024-08-08 13:47:47.277108: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faaac001d00 of size 256 next 39
# 2024-08-08 13:47:47.277121: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7faa
I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 929280 totalling 907.5KiB
# 2024-08-08 13:47:47.298418: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 975616 totalling 952.8KiB
# 2024-08-08 13:47:47.298424: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1073920 totalling 1.02MiB
# 2024-08-08 13:47:47.298430: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1284096 totalling 1.22MiB
# 2024-08-08 13:47:47.298436: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1512448 totalling 1.44MiB
# 2024-08-08 13:47:47.298443: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 1572864 totalling 10.50MiB
# 2024-08-08 13:47:47.298449: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1689600 totalling 1.61MiB
# 2024-08-08 13:47:47.298454: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 2097152 totalling 6.00MiB
# 2024-08-08 13:47:47.298461: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 35 Chunks of size 2217984 totalling 74.03MiB
# 2024-08-08 13:47:47.298467: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 2568192 totalling 4.90MiB
# 2024-08-08 13:47:47.298473: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2758144 totalling 2.63MiB
# 2024-08-08 13:47:47.298479: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 3735552 totalling 7.12MiB
# 2024-08-08 13:47:47.298485: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 4194304 totalling 12.00MiB
# 2024-08-08 13:47:47.298492: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 6291456 totalling 42.00MiB
# 2024-08-08 13:47:47.298498: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 8388608 totalling 40.00MiB
# 2024-08-08 13:47:47.298504: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 8792064 totalling 8.38MiB
# 2024-08-08 13:47:47.298510: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 9080832 totalling 8.66MiB
# 2024-08-08 13:47:47.298516: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 9689088 totalling 9.24MiB
# 2024-08-08 13:47:47.298522: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 11206656 totalling 10.69MiB
# 2024-08-08 13:47:47.298529: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 231211008 totalling 220.50MiB
# 2024-08-08 13:47:47.298536: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 543.03MiB
# 2024-08-08 13:47:47.298542: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 986251264 memory_limit_: 986251264 available bytes: 0 curr_region_allocation_bytes_: 1972502528
# 2024-08-08 13:47:47.298554: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                       986251264
# InUse:                       569413120
# MaxInUse:                    978594048
# NumAllocs:                     3661916
# MaxAllocSize:                342729984
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-08-08 13:47:47.298680: W tensorflow/tsl/framework/bfc_allocator.cc:497] ********_*****_*__*********************************_______*************************_________________
# 2024-08-08 13:47:47.298708: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at fused_batch_norm_op.cc:1565 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,112,112,144] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Train the model
# ----> 2 history = model.fit(
#       3     train_generator,
#       4     steps_per_epoch=train_generator.samples // batch_size,
#       5     validation_data=validation_generator,
#       6     validation_steps=validation_generator.samples // batch_size,
#       7     epochs=50,
#       8     callbacks=[checkpoint, early_stopping]
#       9 )
#
# File /usr/local/lib/python3.8/dist-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'model_2/block2a_expand_bn/FusedBatchNormV3' defined at (most recent call last):
#     File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/home/user/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/user/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 1046, in launch_instance
#       app.start()
#     File "/home/user/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/home/user/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#       handle._run()
#     File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/user/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "/home/user/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "/home/user/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "/home/user/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "/home/user/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/home/user/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/user/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/home/user/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/home/user/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/user/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/user/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/user/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_644638/1310545296.py", line 2, in <module>
#       history = model.fit(
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py", line 1742, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py", line 1338, in train_function
#       return step_function(self, iterator)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py", line 1322, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py", line 1303, in run_step
#       outputs = model.train_step(data)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py", line 1080, in train_step
#       y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py", line 569, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/engine/base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/layers/normalization/batch_normalization.py", line 597, in call
#       outputs = self._fused_batch_norm(
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/layers/normalization/batch_normalization.py", line 990, in _fused_batch_norm
#       output, mean, variance = control_flow_util.smart_cond(
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/utils/control_flow_util.py", line 108, in smart_cond
#       return tf.__internal__.smart_cond.smart_cond(
#     File "/usr/local/lib/python3.8/dist-packages/keras/src/layers/normalization/batch_normalization.py", line 979, in _fused_batch_norm_inference
#       return tf.compat.v1.nn.fused_batch_norm(
# Node: 'model_2/block2a_expand_bn/FusedBatchNormV3'
# OOM when allocating tensor with shape[32,112,112,144] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model_2/block2a_expand_bn/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_214405]

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')

# %% [markdown]
# # Architecture No 5

# %%
# Load the EfficienNetB5 model pretrained on ImageNet
base_model = EfficientNetB5(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-4:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_5.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Architecture No 6

# %%
# Load the EfficientNetB5 model pretrained on ImageNet
base_model = EfficientNetB5(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-4:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
top_model = Dropout(0.3)(top_model)
top_model = Dense(64, activation='relu', name = 'Dense_64')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_6.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Architecture No 7

# %%
# Load the EfficientNetB5 model pretrained on ImageNet
base_model = EfficientNetB5(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-4:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(2048, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(1024, activation='relu', name = 'Dense_512')(top_model)
top_model = Dropout(0.3)(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_64')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_7.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
