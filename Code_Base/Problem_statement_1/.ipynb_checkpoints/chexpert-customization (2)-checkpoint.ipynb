# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def pre_process_dataset_train_n_valid(file_name):
    try:
        train_full_df = pd.read_csv(file_name,index_col=False)

        #Spliting/ Extracting Validation Dataset from Training Data
        train_df, validation_df = train_test_split(train_full_df, test_size = 0.2, random_state = 420, shuffle = True)
        
        # Handling NaN values
        train_df = train_df.fillna(0)
        validation_df = validation_df.fillna(0)
        
        # Handling -1 values
        train_df = train_df.replace(-1,0)
        validation_df = validation_df.replace(-1,0)
        
        
        # Re-ordering the columns
        reordered_columns = ["Path","Atelectasis","Cardiomegaly","Consolidation","Edema","Pleural Effusion",
                            "Pleural Other","Pneumonia","Pneumothorax","Enlarged Cardiomediastinum",
                            "Lung Opacity","Lung Lesion","Fracture","Support Devices","No Finding"]
        
        
        train_df = train_df[reordered_columns]        
        validation_df = validation_df[reordered_columns]
        
        # Converting Datatype of the columns to Int type
        train_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia',
                  'Pneumothorax','Enlarged Cardiomediastinum', 'Lung Opacity', 'Lung Lesion', 'Fracture', 'Support Devices', 'No Finding']] = train_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax','Enlarged Cardiomediastinum', 
                                                                                                                                                          'Lung Opacity', 'Lung Lesion', 'Fracture','Support Devices', 'No Finding']].astype('int')
        
        validation_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia',
                  'Pneumothorax','Enlarged Cardiomediastinum', 'Lung Opacity', 'Lung Lesion', 'Fracture', 'Support Devices', 'No Finding']] = validation_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax','Enlarged Cardiomediastinum', 
                                                                                                                                                          'Lung Opacity', 'Lung Lesion', 'Fracture','Support Devices', 'No Finding']].astype('int')
        # Re-naming the Cols
        train_df.rename(columns={'Pleural Effusion':'Pleural_Effusion','Pleural Other':'Pleural_Other','Enlarged Cardiomediastinum':'Enlarged_Cardiomediastinum','Lung Opacity':'Lung_Opacity','Lung Lesion':'Lung_Lesion','Support Devices':'Support_Devices','No Finding':'No_Finding'}, inplace=True)
        train_df.reset_index(drop=True)
        
        validation_df.rename(columns={'Pleural Effusion':'Pleural_Effusion','Pleural Other':'Pleural_Other','Enlarged Cardiomediastinum':'Enlarged_Cardiomediastinum','Lung Opacity':'Lung_Opacity','Lung Lesion':'Lung_Lesion','Support Devices':'Support_Devices','No Finding':'No_Finding'}, inplace=True)
        validation_df.reset_index(drop=True)
        
#         list_of_path_for_train_image = []
#         list_of_labels_for_train_image = []
        
#         for row in train_df.itertuples():            
#             y_labels = str(row.Atelectasis) + ',' + str(row.Cardiomegaly) + ',' + str(row.Consolidation) + ',' + str(row.Edema) + ',' + str(row.Pleural_Effusion) + ',' + str(row.Pleural_Other) + ',' +str(row.Pneumonia) + ',' + str(row.Pneumothorax) + ',' + str(row.Enlarged_Cardiomediastinum) + ',' + str(row.Lung_Opacity) + ',' + str(row.Lung_Lesion) + ',' + str(row.Fracture) + ',' + str(row.Support_Devices) + ',' + str(row.No_Finding)
#             list_of_path_for_train_image.append(row.Path)
#             list_of_labels_for_train_image.append(y_labels)
            
        
#         list_of_path_for_validation_image = []
#         list_of_labels_for_validation_image = []
        
#         for row in validation_df.itertuples():            
#             y_labels = str(row.Atelectasis) + ',' + str(row.Cardiomegaly) + ',' + str(row.Consolidation) + ',' + str(row.Edema) + ',' + str(row.Pleural_Effusion) + ',' + str(row.Pleural_Other) + ',' +str(row.Pneumonia) + ',' + str(row.Pneumothorax) + ',' + str(row.Enlarged_Cardiomediastinum) + ',' + str(row.Lung_Opacity) + ',' + str(row.Lung_Lesion) + ',' + str(row.Fracture) + ',' + str(row.Support_Devices) + ',' + str(row.No_Finding)
#             list_of_path_for_validation_image.append(row.Path)
#             list_of_labels_for_validation_image.append(y_labels)
            
#         df_train_final =  pd.DataFrame(zip(list_of_path_for_train_image,list_of_labels_for_train_image),columns=['Path', 'Labels'])
#         df_validation_final =  pd.DataFrame(zip(list_of_path_for_validation_image,list_of_labels_for_validation_image),columns=['Path', 'Labels'])
        
#         return df_train_final, df_validation_final
        return train_df, validation_df
        
        
    except Exception as err:
        print('Info:', err)

# %%
def pre_process_dataset_test(file_name):
    try:
        test_full_df = pd.read_csv(file_name, index_col=None)
        
        test_df = test_full_df.fillna(0)
        
        test_df = test_df.replace(-1,0)
        
        # Re-ordering the columns
        reordered_columns = ["Path","Atelectasis","Cardiomegaly","Consolidation","Edema","Pleural Effusion",
                            "Pleural Other","Pneumonia","Pneumothorax","Enlarged Cardiomediastinum",
                            "Lung Opacity","Lung Lesion","Fracture","Support Devices","No Finding"]
        
        test_df = test_df[reordered_columns]       
        
        # Converting Datatype of the columns to Int type
        test_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia',
                  'Pneumothorax','Enlarged Cardiomediastinum', 'Lung Opacity', 'Lung Lesion', 'Fracture', 'Support Devices', 'No Finding']] = test_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax','Enlarged Cardiomediastinum','Lung Opacity', 'Lung Lesion', 'Fracture','Support Devices', 'No Finding']].astype('int') 
        
        # Re-naming the Cols
        test_df.rename(columns={'Pleural Effusion':'Pleural_Effusion','Pleural Other':'Pleural_Other','Enlarged Cardiomediastinum':'Enlarged_Cardiomediastinum','Lung Opacity':'Lung_Opacity','Lung Lesion':'Lung_Lesion','Support Devices':'Support_Devices','No Finding':'No_Finding'}, inplace=True)
        
#         list_of_path_for_test_image = []
#         list_of_labels_for_test_image = []
        
#         for row in test_df.itertuples():            
#             y_labels = str(row.Atelectasis) + ',' + str(row.Cardiomegaly) + ',' + str(row.Consolidation) + ',' + str(row.Edema) + ',' + str(row.Pleural_Effusion) + ',' + str(row.Pleural_Other) + ',' +str(row.Pneumonia) + ',' + str(row.Pneumothorax) + ',' + str(row.Enlarged_Cardiomediastinum) + ',' + str(row.Lung_Opacity) + ',' + str(row.Lung_Lesion) + ',' + str(row.Fracture) + ',' + str(row.Support_Devices) + ',' + str(row.No_Finding)
#             list_of_path_for_test_image.append(row.Path)
#             list_of_labels_for_test_image.append(y_labels)
        
#         df_test_final =  pd.DataFrame(zip(list_of_path_for_test_image,list_of_labels_for_test_image),columns=['Path', 'Labels'])
        
#         return df_test_final
        return test_df
    except Exception as err:
        print('Info:', err)

# %%
train_file_name = '/kaggle/input/chexpert/CheXpert-v1.0-small/train.csv'

# %%
train_df, validation_df = pre_process_dataset_train_n_valid(train_file_name)

# %%
train_df.head(10)

# %%
validation_df.head(10)

# %%
test_file_name = '/kaggle/input/chexpert/CheXpert-v1.0-small/valid.csv'

# %%
test_df = pre_process_dataset_test(test_file_name)

# %%
test_df.head(10)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import cv2
from tqdm import tqdm
from sklearn.utils import shuffle

# %%
from tensorflow.keras import applications
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import accuracy_score

# %%
def expand_grayscale_image_channels(gray_image):
    try:
        gray_image_arr = np.array(gray_image)
        gray_image_arr = np.expand_dims(gray_image_arr, -1)
        gray_image_arr_3_channel = gray_image_arr.repeat(3, axis=-1)
        return gray_image_arr_3_channel
    except Exception as err:
        print('Info:', err)

# %%
columns = ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema',
       'Pleural_Effusion', 'Pleural_Other', 'Pneumonia', 'Pneumothorax',
       'Enlarged_Cardiomediastinum', 'Lung_Opacity', 'Lung_Lesion', 'Fracture',
       'Support_Devices', 'No_Finding']

# %%
datagen = ImageDataGenerator(rotation_range=15,
                            brightness_range= [0.6,1],
                            width_shift_range = 0.1,
                            height_shift_range = 0.1,
                            horizontal_flip = False,
                            vertical_flip= False,
                            preprocessing_function= preprocess_input)

# %%
test_datagen = ImageDataGenerator(preprocessing_function= preprocess_input)

# %%
train_generator = datagen.flow_from_dataframe(dataframe=train_df[:50000],directory="/kaggle/input/chexpert", x_col="Path",y_col=columns,batch_size=64,seed=42,shuffle=True,
                                                class_mode="raw",target_size=(150,150))

# %%
valid_generator = datagen.flow_from_dataframe(dataframe=validation_df[:15000],directory="/kaggle/input/chexpert", x_col="Path",y_col=columns,batch_size=64,seed=42,shuffle=True,
                                                class_mode="raw",target_size=(150,150))

# %%
test_generator = test_datagen.flow_from_dataframe(dataframe=test_df,directory="/kaggle/input/chexpert", x_col="Path",y_col=columns,batch_size=64,seed=42,shuffle=True,
                                                class_mode="raw",target_size=(150,150))

# %%
conv_base = VGG16(include_top = False, weights='/kaggle/input/keras-pretrained-models/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5', input_shape = (150,150,3))

# %%
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %%
top_model = conv_base.output
top_model = Flatten(name="Flatten")(top_model)
top_model = Dense(1024, activation = 'relu', name= 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name= 'Dense_512')(top_model)
output_layer = Dense(14, activation = 'softmax',name= 'Output_Layer')(top_model)

# %%
model = Model(inputs= conv_base.input, outputs = output_layer)

# %%
model.summary()

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size # 781
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size #234
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size #3

# %%
STEP_SIZE_TRAIN

# %%
STEP_SIZE_VALID

# %%
STEP_SIZE_TEST

# %%
optim_1 = Adam(learning_rate = 0.0001)

# %%
model.compile(optimizer = optim_1, loss = "binary_crossentropy", metrics=["accuracy"])

# %%
model.fit_generator(generator=train_generator,steps_per_epoch=STEP_SIZE_TRAIN, validation_data=valid_generator, validation_steps=STEP_SIZE_VALID, epochs=50)

# %% [markdown]
# **Version 2**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf

# %%
def pre_process_dataset_train_n_valid(file_name):
    try:
        train_full_df = pd.read_csv(file_name,index_col=False)

        #Spliting/ Extracting Validation Dataset from Training Data
        train_df, validation_df = train_test_split(train_full_df, test_size = 0.2, random_state = 420, shuffle = True)
        
        # Handling NaN values
        train_df = train_df.fillna(0)
        validation_df = validation_df.fillna(0)
        
        # Handling -1 values
        train_df = train_df.replace(-1,0)
        validation_df = validation_df.replace(-1,0)
        
        
        # Re-ordering the columns
        reordered_columns = ["Path","Atelectasis","Cardiomegaly","Consolidation","Edema","Pleural Effusion",
                            "Pleural Other","Pneumonia","Pneumothorax","Enlarged Cardiomediastinum",
                            "Lung Opacity","Lung Lesion","Fracture","Support Devices","No Finding"]
        
        
        train_df = train_df[reordered_columns]        
        validation_df = validation_df[reordered_columns]
        
        # Converting Datatype of the columns to Int type
        train_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia',
                  'Pneumothorax','Enlarged Cardiomediastinum', 'Lung Opacity', 'Lung Lesion', 'Fracture', 'Support Devices', 'No Finding']] = train_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax','Enlarged Cardiomediastinum', 
                                                                                                                                                          'Lung Opacity', 'Lung Lesion', 'Fracture','Support Devices', 'No Finding']].astype('int')
        
        validation_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia',
                  'Pneumothorax','Enlarged Cardiomediastinum', 'Lung Opacity', 'Lung Lesion', 'Fracture', 'Support Devices', 'No Finding']] = validation_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax','Enlarged Cardiomediastinum', 
                                                                                                                                                          'Lung Opacity', 'Lung Lesion', 'Fracture','Support Devices', 'No Finding']].astype('int')
        # Re-naming the Cols
        train_df.rename(columns={'Pleural Effusion':'Pleural_Effusion','Pleural Other':'Pleural_Other','Enlarged Cardiomediastinum':'Enlarged_Cardiomediastinum','Lung Opacity':'Lung_Opacity','Lung Lesion':'Lung_Lesion','Support Devices':'Support_Devices','No Finding':'No_Finding'}, inplace=True)
        train_df.reset_index(drop=True)
        
        validation_df.rename(columns={'Pleural Effusion':'Pleural_Effusion','Pleural Other':'Pleural_Other','Enlarged Cardiomediastinum':'Enlarged_Cardiomediastinum','Lung Opacity':'Lung_Opacity','Lung Lesion':'Lung_Lesion','Support Devices':'Support_Devices','No Finding':'No_Finding'}, inplace=True)
        validation_df.reset_index(drop=True)
        
#         list_of_path_for_train_image = []
#         list_of_labels_for_train_image = []
        
#         for row in train_df.itertuples():            
#             y_labels = str(row.Atelectasis) + ',' + str(row.Cardiomegaly) + ',' + str(row.Consolidation) + ',' + str(row.Edema) + ',' + str(row.Pleural_Effusion) + ',' + str(row.Pleural_Other) + ',' +str(row.Pneumonia) + ',' + str(row.Pneumothorax) + ',' + str(row.Enlarged_Cardiomediastinum) + ',' + str(row.Lung_Opacity) + ',' + str(row.Lung_Lesion) + ',' + str(row.Fracture) + ',' + str(row.Support_Devices) + ',' + str(row.No_Finding)
#             list_of_path_for_train_image.append(row.Path)
#             list_of_labels_for_train_image.append(y_labels)
            
        
#         list_of_path_for_validation_image = []
#         list_of_labels_for_validation_image = []
        
#         for row in validation_df.itertuples():            
#             y_labels = str(row.Atelectasis) + ',' + str(row.Cardiomegaly) + ',' + str(row.Consolidation) + ',' + str(row.Edema) + ',' + str(row.Pleural_Effusion) + ',' + str(row.Pleural_Other) + ',' +str(row.Pneumonia) + ',' + str(row.Pneumothorax) + ',' + str(row.Enlarged_Cardiomediastinum) + ',' + str(row.Lung_Opacity) + ',' + str(row.Lung_Lesion) + ',' + str(row.Fracture) + ',' + str(row.Support_Devices) + ',' + str(row.No_Finding)
#             list_of_path_for_validation_image.append(row.Path)
#             list_of_labels_for_validation_image.append(y_labels)
            
#         df_train_final =  pd.DataFrame(zip(list_of_path_for_train_image,list_of_labels_for_train_image),columns=['Path', 'Labels'])
#         df_validation_final =  pd.DataFrame(zip(list_of_path_for_validation_image,list_of_labels_for_validation_image),columns=['Path', 'Labels'])
        
#         return df_train_final, df_validation_final
        return train_df, validation_df
        
        
    except Exception as err:
        print('Info:', err)

# %%
def pre_process_dataset_test(file_name):
    try:
        test_full_df = pd.read_csv(file_name, index_col=None)
        
        test_df = test_full_df.fillna(0)
        
        test_df = test_df.replace(-1,0)
        
        # Re-ordering the columns
        reordered_columns = ["Path","Atelectasis","Cardiomegaly","Consolidation","Edema","Pleural Effusion",
                            "Pleural Other","Pneumonia","Pneumothorax","Enlarged Cardiomediastinum",
                            "Lung Opacity","Lung Lesion","Fracture","Support Devices","No Finding"]
        
        test_df = test_df[reordered_columns]       
        
        # Converting Datatype of the columns to Int type
        test_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia',
                  'Pneumothorax','Enlarged Cardiomediastinum', 'Lung Opacity', 'Lung Lesion', 'Fracture', 'Support Devices', 'No Finding']] = test_df[['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema','Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax','Enlarged Cardiomediastinum','Lung Opacity', 'Lung Lesion', 'Fracture','Support Devices', 'No Finding']].astype('int') 
        
        # Re-naming the Cols
        test_df.rename(columns={'Pleural Effusion':'Pleural_Effusion','Pleural Other':'Pleural_Other','Enlarged Cardiomediastinum':'Enlarged_Cardiomediastinum','Lung Opacity':'Lung_Opacity','Lung Lesion':'Lung_Lesion','Support Devices':'Support_Devices','No Finding':'No_Finding'}, inplace=True)
        
#         list_of_path_for_test_image = []
#         list_of_labels_for_test_image = []
        
#         for row in test_df.itertuples():            
#             y_labels = str(row.Atelectasis) + ',' + str(row.Cardiomegaly) + ',' + str(row.Consolidation) + ',' + str(row.Edema) + ',' + str(row.Pleural_Effusion) + ',' + str(row.Pleural_Other) + ',' +str(row.Pneumonia) + ',' + str(row.Pneumothorax) + ',' + str(row.Enlarged_Cardiomediastinum) + ',' + str(row.Lung_Opacity) + ',' + str(row.Lung_Lesion) + ',' + str(row.Fracture) + ',' + str(row.Support_Devices) + ',' + str(row.No_Finding)
#             list_of_path_for_test_image.append(row.Path)
#             list_of_labels_for_test_image.append(y_labels)
        
#         df_test_final =  pd.DataFrame(zip(list_of_path_for_test_image,list_of_labels_for_test_image),columns=['Path', 'Labels'])
        
#         return df_test_final
        return test_df
    except Exception as err:
        print('Info:', err)

# %%
train_file_name = '/kaggle/input/chexpert/CheXpert-v1.0-small/train.csv'

# %%
train_df, validation_df = pre_process_dataset_train_n_valid(train_file_name)

# %%
test_file_name = '/kaggle/input/chexpert/CheXpert-v1.0-small/valid.csv'

# %%
test_df = pre_process_dataset_test(test_file_name)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import cv2
from tqdm import tqdm
from sklearn.utils import shuffle

# %%
from tensorflow.keras import applications
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import accuracy_score
from tensorflow.keras.layers import Lambda, Input
from tensorflow.keras.layers import RepeatVector

# %%
def expand_grayscale_image_channels(gray_image):
    try:
        gray_image_arr = np.array(gray_image)
        gray_image_arr = np.expand_dims(gray_image_arr, -1)
        gray_image_arr_3_channel = gray_image_arr.repeat(3, axis=-1)
        return gray_image_arr_3_channel
    except Exception as err:
        print('Info:', err)

# %%
columns = ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema',
       'Pleural_Effusion', 'Pleural_Other', 'Pneumonia', 'Pneumothorax',
       'Enlarged_Cardiomediastinum', 'Lung_Opacity', 'Lung_Lesion', 'Fracture',
       'Support_Devices', 'No_Finding']

# %%
datagen = ImageDataGenerator(rotation_range=15,
                            brightness_range= [0.6,1],
                            width_shift_range = 0.1,
                            height_shift_range = 0.1,
                            horizontal_flip = False,
                            vertical_flip= False)
                            #preprocessing_function= expand_grayscale_image_channels)

# %%
test_datagen = ImageDataGenerator()

# %%
train_generator = datagen.flow_from_dataframe(dataframe=train_df[:10000],directory="/kaggle/input/chexpert", x_col="Path",y_col=columns,batch_size=64,seed=42,shuffle=True,
                                                class_mode="raw",target_size=(224,224))
# Out:
# Found 10000 validated image filenames.

# %%
valid_generator = datagen.flow_from_dataframe(dataframe=validation_df[:3000],directory="/kaggle/input/chexpert", x_col="Path",y_col=columns,batch_size=64,seed=42,shuffle=True,
                                                class_mode="raw",target_size=(224,224))
# Out:
# Found 3000 validated image filenames.

# %%
test_df.set_index('Path', drop=True)
# Out:
#                                                     Atelectasis  Cardiomegaly  \
# Path
# CheXpert-v1.0-small/valid/patient64541/study1/v...            0             1
# CheXpert-v1.0-small/valid/patient64542/study1/v...            0             0
# CheXpert-v1.0-small/valid/patient64542/study1/v...            0             0
# CheXpert-v1.0-small/valid/patient64543/study1/v...            0             0
# CheXpert-v1.0-small/valid/patient64544/study1/v...            0             0
# ...                                                         ...           ...
# CheXpert-v1.0-small/valid/patient64736/study1/v...            0             0
# CheXpert-v1.0-small/valid/patient64737/study1/v...            0             0
# CheXpert-v1.0-small/valid/patient64738/study1/v...            0             1
# CheXpert-v1.0-small/valid/patient64739/study1/v...            0             0
# CheXpert-v1.0-small/valid/patient64740/study1/v...            1             0
#
#                                                     Consolidation  Edema  \
# Path
# CheXpert-v1.0-small/valid/patient64541/study1/v...              0      0
# CheXpert-v1.0-small/valid/patient64542/study1/v...              0      0
# CheXpert-v1.0-small/valid/patient64542/study1/v...              0      0
# CheXpert-v1.0-small/valid/patient64543/study1/v...              0      1
# CheXpert-v1.0-small/valid/patient64544/study1/v...              0      0
# ...                                                           ...    ...
# CheXpert-v1.0-small/valid/patient64736/study1/v...              0      0
# CheXpert-v1.0-small/valid/patient64737/study1/v...              0      0
# CheXpert-v1.0-small/valid/patient64738/study1/v...              0      1
# CheXpert-v1.0-small/valid/patient64739/study1/v...              0      0
# CheXpert-v1.0-small/valid/patient64740/study1/v...              0      0
#
#                                                     Pleural_Effusion  \
# Path
# CheXpert-v1.0-small/valid/patient64541/study1/v...                 0
# CheXpert-v1.0-small/valid/patient64542/study1/v...                 0
# CheXpert-v1.0-small/valid/patient64542/study1/v...                 0
# CheXpert-v1.0-small/valid/patient64543/study1/v...                 0
# CheXpert-v1.0-small/valid/patient64544/study1/v...                 0
# ...                                                              ...
# CheXpert-v1.0-small/valid/patient64736/study1/v...                 0
# CheXpert-v1.0-small/valid/patient64737/study1/v...                 0
# CheXpert-v1.0-small/valid/patient64738/study1/v...                 0
# CheXpert-v1.0-small/valid/patient64739/study1/v...                 0
# CheXpert-v1.0-small/valid/patient64740/study1/v...                 1
#
#                                                     Pleural_Other  Pneumonia  \
# Path
# CheXpert-v1.0-small/valid/patient64541/study1/v...              0          0
# CheXpert-v1.0-small/valid/patient64542/study1/v...              0          0
# CheXpert-v1.0-small/valid/patient64542/study1/v...              0          0
# CheXpert-v1.0-small/valid/patient64543/study1/v...              0          0
# CheXpert-v1.0-small/valid/patient64544/study1/v...              0          0
# ...                                                           ...        ...
# CheXpert-v1.0-small/valid/patient64736/study1/v...              0          0
# CheXpert-v1.0-small/valid/patient64737/study1/v...              0          0
# CheXpert-v1.0-small/valid/patient64738/study1/v...              0          0
# CheXpert-v1.0-small/valid/patient64739/study1/v...              0          0
# CheXpert-v1.0-small/valid/patient64740/study1/v...              0          0
#
#                                                     Pneumothorax  \
# Path
# CheXpert-v1.0-small/valid/patient64541/study1/v...             0
# CheXpert-v1.0-small/valid/patient64542/study1/v...             0
# CheXpert-v1.0-small/valid/patient64542/study1/v...             0
# CheXpert-v1.0-small/valid/patient64543/study1/v...             0
# CheXpert-v1.0-small/valid/patient64544/study1/v...             0
# ...                                                          ...
# CheXpert-v1.0-small/valid/patient64736/study1/v...             0
# CheXpert-v1.0-small/valid/patient64737/study1/v...             0
# CheXpert-v1.0-small/valid/patient64738/study1/v...             0
# CheXpert-v1.0-small/valid/patient64739/study1/v...             0
# CheXpert-v1.0-small/valid/patient64740/study1/v...             0
#
#                                                     Enlarged_Cardiomediastinum  \
# Path
# CheXpert-v1.0-small/valid/patient64541/study1/v...                           1
# CheXpert-v1.0-small/valid/patient64542/study1/v...                           0
# CheXpert-v1.0-small/valid/patient64542/study1/v...                           0
# CheXpert-v1.0-small/valid/patient64543/study1/v...                           1
# CheXpert-v1.0-small/valid/patient64544/study1/v...                           0
# ...                                                                        ...
# CheXpert-v1.0-small/valid/patient64736/study1/v...                           0
# CheXpert-v1.0-small/valid/patient64737/study1/v...                           0
# CheXpert-v1.0-small/valid/patient64738/study1/v...                           1
# CheXpert-v1.0-small/valid/patient64739/study1/v...                           1
# CheXpert-v1.0-small/valid/patient64740/study1/v...                           1
#
#                                                     Lung_Opacity  Lung_Lesion  \
# Path
# CheXpert-v1.0-small/valid/patient64541/study1/v...             1            0
# CheXpert-v1.0-small/valid/patient64542/study1/v...             0            0
# CheXpert-v1.0-small/valid/patient64542/study1/v...             0            0
# CheXpert-v1.0-small/valid/patient64543/study1/v...             1            0
# CheXpert-v1.0-small/valid/patient64544/study1/v...             0            0
# ...                                                          ...          ...
# CheXpert-v1.0-small/valid/patient64736/study1/v...             0            0
# CheXpert-v1.0-small/valid/patient64737/study1/v...             0            0
# CheXpert-v1.0-small/valid/patient64738/study1/v...             1            0
# CheXpert-v1.0-small/valid/patient64739/study1/v...             0            0
# CheXpert-v1.0-small/valid/patient64740/study1/v...             1            0
#
#                                                     Fracture  Support_Devices  \
# Path
# CheXpert-v1.0-small/valid/patient64541/study1/v...         0                0
# CheXpert-v1.0-small/valid/patient64542/study1/v...         0                1
# CheXpert-v1.0-small/valid/patient64542/study1/v...         0                1
# CheXpert-v1.0-small/valid/patient64543/study1/v...         0                0
# CheXpert-v1.0-small/valid/patient64544/study1/v...         0                0
# ...                                                      ...              ...
# CheXpert-v1.0-small/valid/patient64736/study1/v...         0                1
# CheXpert-v1.0-small/valid/patient64737/study1/v...         0                1
# CheXpert-v1.0-small/valid/patient64738/study1/v...         0                1
# CheXpert-v1.0-small/valid/patient64739/study1/v...         0                0
# CheXpert-v1.0-small/valid/patient64740/study1/v...         0                0
#
#                                                     No_Finding
# Path
# CheXpert-v1.0-small/valid/patient64541/study1/v...           0
# CheXpert-v1.0-small/valid/patient64542/study1/v...           0
# CheXpert-v1.0-small/valid/patient64542/study1/v...           0
# CheXpert-v1.0-small/valid/patient64543/study1/v...           0
# CheXpert-v1.0-small/valid/patient64544/study1/v...           1
# ...                                                        ...
# CheXpert-v1.0-small/valid/patient64736/study1/v...           0
# CheXpert-v1.0-small/valid/patient64737/study1/v...           0
# CheXpert-v1.0-small/valid/patient64738/study1/v...           0
# CheXpert-v1.0-small/valid/patient64739/study1/v...           0
# CheXpert-v1.0-small/valid/patient64740/study1/v...           0
#
# [234 rows x 14 columns]

# %%
test_generator = test_datagen.flow_from_dataframe(dataframe=test_df,directory="/kaggle/input/chexpert", x_col="Path",y_col=columns,batch_size=64,seed=42,shuffle=True,
                                                class_mode="raw",target_size=(224,224),validate_filenames=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 test_generator = test_datagen.flow_from_dataframe(dataframe=test_df,directory="/kaggle/input/chexpert", x_col="Path",y_col=columns,batch_size=64,seed=42,shuffle=True,
#       2                                                 class_mode="raw",target_size=(224,224),validate_filenames=True)
#
# File /opt/conda/lib/python3.10/site-packages/keras/preprocessing/image.py:1806, in ImageDataGenerator.flow_from_dataframe(self, dataframe, directory, x_col, y_col, weight_col, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, subset, interpolation, validate_filenames, **kwargs)
#    1799 if "drop_duplicates" in kwargs:
#    1800     warnings.warn(
#    1801         "drop_duplicates is deprecated, you can drop duplicates "
#    1802         "by using the pandas.DataFrame.drop_duplicates method.",
#    1803         DeprecationWarning,
#    1804     )
# -> 1806 return DataFrameIterator(
#    1807     dataframe,
#    1808     directory,
#    1809     self,
#    1810     x_col=x_col,
#    1811     y_col=y_col,
#    1812     weight_col=weight_col,
#    1813     target_size=target_size,
#    1814     color_mode=color_mode,
#    1815     classes=classes,
#    1816     class_mode=class_mode,
#    1817     data_format=self.data_format,
#    1818     batch_size=batch_size,
#    1819     shuffle=shuffle,
#    1820     seed=seed,
#    1821     save_to_dir=save_to_dir,
#    1822     save_prefix=save_prefix,
#    1823     save_format=save_format,
#    1824     subset=subset,
#    1825     interpolation=interpolation,
#    1826     validate_filenames=validate_filenames,
#    1827     dtype=self.dtype,
#    1828 )
#
# File /opt/conda/lib/python3.10/site-packages/keras/preprocessing/image.py:993, in DataFrameIterator.__init__(self, dataframe, directory, image_data_generator, x_col, y_col, weight_col, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, subset, interpolation, keep_aspect_ratio, dtype, validate_filenames)
#     991     self._targets = [np.array(df[col].tolist()) for col in y_col]
#     992 if class_mode == "raw":
# --> 993     self._targets = df[y_col].values
#     994 self.samples = len(self.filenames)
#     995 validated_string = (
#     996     "validated" if validate_filenames else "non-validated"
#     997 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Filename'] not in index"

# %% [markdown]
# **Model Designing**

# %%
conv_base = VGG16(include_top = False, weights='/kaggle/input/keras-pretrained-models/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5', input_shape = (224,224,3))

# %%
for layer in conv_base.layers:
    layer.trainable = False

# %%
inp = Input((224,224,3)) # Input Shape
top_model = conv_base(inp)
top_model = Flatten(name="Flatten")(top_model)
top_model = Dense(1024, activation = 'relu', name= 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name= 'Dense_512')(top_model)
output_layer = Dense(14, activation = 'sigmoid',name= 'Output_Layer')(top_model)

# %%
model = Model(inputs= inp, outputs = output_layer)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  Flatten (Flatten)           (None, 25088)             0
#
#  Dense_1024 (Dense)          (None, 1024)              25691136
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  Dense_512 (Dense)           (None, 512)               524800
#
#  Output_Layer (Dense)        (None, 14)                7182
#
# =================================================================
# Total params: 40,941,902
# Trainable params: 26,225,166
# Non-trainable params: 14,716,736
# _________________________________________________________________

# %%
BATCH_SIZE = 64
input_shape = (224,224,3)
optim_1 = Adam(learning_rate = 0.0001)
n_classes = 14

n_steps = train_generator.samples // BATCH_SIZE
n_val_steps = valid_generator.samples // BATCH_SIZE
n_epochs = 15

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size

# %%
model.compile(optimizer = optim_1, loss = "binary_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(train_generator,steps_per_epoch=STEP_SIZE_TRAIN, validation_data=valid_generator, validation_steps=STEP_SIZE_VALID, epochs=15)
# Out:
# Epoch 1/15
# 156/156 [==============================] - 331s 2s/step - loss: 0.3952 - accuracy: 0.1313 - val_loss: 0.3634 - val_accuracy: 0.1668
# Epoch 2/15
# 156/156 [==============================] - 214s 1s/step - loss: 0.3233 - accuracy: 0.1690 - val_loss: 0.3435 - val_accuracy: 0.1613
# Epoch 3/15
# 156/156 [==============================] - 214s 1s/step - loss: 0.3059 - accuracy: 0.1852 - val_loss: 0.3425 - val_accuracy: 0.1675
# Epoch 4/15
# 156/156 [==============================] - 246s 2s/step - loss: 0.2932 - accuracy: 0.1983 - val_loss: 0.3430 - val_accuracy: 0.1508
# Epoch 5/15
# 156/156 [==============================] - 213s 1s/step - loss: 0.2820 - accuracy: 0.2137 - val_loss: 0.3427 - val_accuracy: 0.1732
# Epoch 6/15
# 156/156 [==============================] - 248s 2s/step - loss: 0.2721 - accuracy: 0.2280 - val_loss: 0.3432 - val_accuracy: 0.1675
# Epoch 7/15
# 156/156 [==============================] - 251s 2s/step - loss: 0.2613 - accuracy: 0.2382 - val_loss: 0.3487 - val_accuracy: 0.1875
# Epoch 8/15
# 156/156 [==============================] - 247s 2s/step - loss: 0.2501 - accuracy: 0.2523 - val_loss: 0.3537 - val_accuracy: 0.1471
# Epoch 9/15
# 156/156 [==============================] - 247s 2s/step - loss: 0.2418 - accuracy: 0.2650 - val_loss: 0.3554 - val_accuracy: 0.1579
# Epoch 10/15
# 156/156 [==============================] - 215s 1s/step - loss: 0.2323 - accuracy: 0.2764 - val_loss: 0.3576 - val_accuracy: 0.1970
# Epoch 11/15
# 156/156 [==============================] - 214s 1s/step - loss: 0.2249 - accuracy: 0.2844 - val_loss: 0.3646 - val_accuracy: 0.1787
# Epoch 12/15
# 156/156 [==============================] - 248s 2s/step - loss: 0.2151 - accuracy: 0.2996 - val_loss: 0.3661 - val_accuracy: 0.1549
# Epoch 13/15
# 156/156 [==============================] - 249s 2s/step - loss: 0.2077 - accuracy: 0.3108 - val_loss: 0.3717 - val_accuracy: 0.1722
# Epoch 14/15
# 156/156 [==============================] - 248s 2s/step - loss: 0.1998 - accuracy: 0.3123 - val_loss: 0.3717 - val_accuracy: 0.1603
# Epoch 15/15
# 156/156 [==============================] - 247s 2s/step - loss: 0.1911 - accuracy: 0.3308 - val_loss: 0.3733 - val_accuracy: 0.1685

# %%
model.save('/kaggle/working/50k_data_vgg16.hdf5')

# %%
epochs = [i for i in range(15)]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
model.load_weights('/kaggle/working/50k_data_vgg16.hdf5')

# %%
test_generator.reset()

# %%
len(test_generator)
# Out:
# 4

# %%
pred=model.predict(test_generator,steps=STEP_SIZE_TEST,verbose=1)
# Out:
# 3/3 [==============================] - 1s 299ms/step

# %%
len(pred)
# Out:
# 192

# %%
pred_bool = (pred >0.5)

# %%
predictions = pred_bool.astype(int)
columns=['Filename','Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema',
       'Pleural_Effusion', 'Pleural_Other', 'Pneumonia', 'Pneumothorax',
       'Enlarged_Cardiomediastinum', 'Lung_Opacity', 'Lung_Lesion', 'Fracture',
       'Support_Devices', 'No_Finding']

# %%
len(predictions)
# Out:
# 192

# %%
#columns should be the same order of y_col
results=pd.DataFrame(columns=columns)

# %%
results
# Out:
#                                               Filename Atelectasis  \
# 0    CheXpert-v1.0-small/valid/patient64541/study1/...         NaN
# 1    CheXpert-v1.0-small/valid/patient64542/study1/...         NaN
# 2    CheXpert-v1.0-small/valid/patient64542/study1/...         NaN
# 3    CheXpert-v1.0-small/valid/patient64543/study1/...         NaN
# 4    CheXpert-v1.0-small/valid/patient64544/study1/...         NaN
# ..                                                 ...         ...
# 229  CheXpert-v1.0-small/valid/patient64736/study1/...         NaN
# 230  CheXpert-v1.0-small/valid/patient64737/study1/...         NaN
# 231  CheXpert-v1.0-small/valid/patient64738/study1/...         NaN
# 232  CheXpert-v1.0-small/valid/patient64739/study1/...         NaN
# 233  CheXpert-v1.0-small/valid/patient64740/study1/...         NaN
#
#     Cardiomegaly Consolidation Edema Pleural_Effusion Pleural_Other Pneumonia  \
# 0            NaN           NaN   NaN              NaN           NaN       NaN
# 1            NaN           NaN   NaN              NaN           NaN       NaN
# 2            NaN           NaN   NaN              NaN           NaN       NaN
# 3            NaN           NaN   NaN              NaN           NaN       NaN
# 4            NaN           NaN   NaN              NaN           NaN       NaN
# ..           ...           ...   ...              ...           ...       ...
# 229          NaN           NaN   NaN              NaN           NaN       NaN
# 230          NaN           NaN   NaN              NaN           NaN       NaN
# 231          NaN           NaN   NaN              NaN           NaN       NaN
# 232          NaN           NaN   NaN              NaN           NaN       NaN
# 233          NaN           NaN   NaN              NaN           NaN       NaN
#
#     Pneumothorax Enlarged_Cardiomediastinum Lung_Opacity Lung_Lesion Fracture  \
# 0            NaN                        NaN          NaN         NaN      NaN
# 1            NaN                        NaN          NaN         NaN      NaN
# 2            NaN                        NaN          NaN         NaN      NaN
# 3            NaN                        NaN          NaN         NaN      NaN
# 4            NaN                        NaN          NaN         NaN      NaN
# ..           ...                        ...          ...         ...      ...
# 229          NaN                        NaN          NaN         NaN      NaN
# 230          NaN                        NaN          NaN         NaN      NaN
# 231          NaN                        NaN          NaN         NaN      NaN
# 232          NaN                        NaN          NaN         NaN      NaN
# 233          NaN                        NaN          NaN         NaN      NaN
#
#     Support_Devices No_Finding
# 0               NaN        NaN
# 1               NaN        NaN
# 2               NaN        NaN
# 3               NaN        NaN
# 4               NaN        NaN
# ..              ...        ...
# 229             NaN        NaN
# 230             NaN        NaN
# 231             NaN        NaN
# 232             NaN        NaN
# 233             NaN        NaN
#
# [234 rows x 15 columns]

# %%
results['Filename']=test_generator.filenames

# %%
len(test_generator.filenames)
# Out:
# 234

# %%
results=results[ordered_cols]#To get the same column order
results.to_csv("/kaggle/working/results.csv",index=False)

# %%
predictions=[]
labels = train_generator.class_indices
labels = dict((v,k) for k,v in labels.items())
for row in pred_bool:
    l=[]
    for index,cls in enumerate(row):
        if cls:
            l.append(label[index])
    predictions.append(",".join(l))
filenames=test_generator.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":predictions})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 predictions=[]
# ----> 2 labels = train_generator.class_indices
#       3 labels = dict((v,k) for k,v in labels.items())
#       4 for row in pred_bool:
#
# AttributeError: 'DataFrameIterator' object has no attribute 'class_indices'

# %%
train_generator.class_indices
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 train_generator.class_indices
#
# AttributeError: 'DataFrameIterator' object has no attribute 'class_indices'
