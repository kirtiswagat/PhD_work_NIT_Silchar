# %%
import os
import shutil
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input, Flatten, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from itertools import cycle
# Out:
# 2024-09-08 11:57:25.162924: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-08 11:57:25.214431: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-08 11:57:25.933233: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, fbeta_score
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

# %%
gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

# %%
# Define paths
base_dir = '/home/user/GPU_CSE/Kirti/Dataset_for_Code_Development/Dataset_for_5_classes_by_Sir/EfficientNetB2'
dataset_dir = '/home/user/GPU_CSE/Kirti/Dataset_for_Code_Development/Dataset_for_5_classes_by_Sir/clean_train_partition'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %%
# Parameters
img_height, img_width = 224, 224 # EfficientNetB1 requires images of size 224x224
batch_size = 32
num_classes = len(next(os.walk(dataset_dir))[1])  # number of class folders
train_ratio = 0.7
validation_ratio = 0.15
test_ratio = 0.15

# %%
# Function to create train, validation, and test splits
def create_splits():
    try:
        if not os.path.exists(train_dir):
            os.makedirs(train_dir)
        if not os.path.exists(validation_dir):
            os.makedirs(validation_dir)
        if not os.path.exists(test_dir):
            os.makedirs(test_dir)
    
        for class_name in os.listdir(dataset_dir):        
            train_class_path = os.path.join(train_dir, class_name)        
            if not os.path.exists(train_class_path):
                os.makedirs(train_class_path)        
            
            test_class_path = os.path.join(test_dir, class_name)        
            if not os.path.exists(test_class_path):
                os.makedirs(test_class_path)        
    
            validation_class_dir = os.path.join(validation_dir, class_name)       
            if not os.path.exists(validation_class_dir):
                os.makedirs(validation_class_dir)        
        
        for class_name in os.listdir(dataset_dir):        
            class_path = os.path.join(dataset_dir, class_name)
            
            if os.path.isdir(class_path):
                images = os.listdir(class_path)
                random.shuffle(images)
                train_split = int(train_ratio * len(images))
                validation_split = int(validation_ratio * len(images))
                
                train_images = images[:train_split]
                validation_images = images[train_split:train_split + validation_split]
                test_images = images[train_split + validation_split:]
    
                for image in train_images:
                    shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name, image))
                for image in validation_images:
                    shutil.copy(os.path.join(class_path, image), os.path.join(validation_dir, class_name, image))
                for image in test_images:
                    shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name, image))
    except Exception as err:
        print("Error:", str(err))

# %%
# Split the dataset
create_splits()

# %%
# Data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    brightness_range=(0.8, 1.2)
)

# %%
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical'
)

validation_generator = val_datagen.flow_from_directory(
    validation_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1083 images belonging to 5 classes.
# Found 230 images belonging to 5 classes.
# Found 239 images belonging to 5 classes.

# %%
# Load the EfficientNetB2 model pretrained on ImageNet
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_1.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Out:
# 2024-09-08 11:57:28.146399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46165 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:86:00.0, compute capability: 8.6

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 2024-09-08 11:57:40.249332: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8905
# 2024-09-08 11:57:40.507523: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-09-08 11:57:40.560604: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fe4b688ea40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-09-08 11:57:40.560631: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-09-08 11:57:40.565517: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-08 11:57:40.750132: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 33/33 [==============================] - ETA: 0s - loss: 1.6758 - accuracy: 0.2055
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 33/33 [==============================] - 25s 474ms/step - loss: 1.6758 - accuracy: 0.2055 - val_loss: 1.6118 - val_accuracy: 0.2009
# Epoch 2/50
# 33/33 [==============================] - 13s 406ms/step - loss: 1.6565 - accuracy: 0.2008 - val_loss: 1.6120 - val_accuracy: 0.1920
# Epoch 3/50
# 33/33 [==============================] - 14s 429ms/step - loss: 1.6269 - accuracy: 0.2093 - val_loss: 1.6099 - val_accuracy: 0.2009
# Epoch 4/50
# 33/33 [==============================] - 13s 405ms/step - loss: 1.6265 - accuracy: 0.2169 - val_loss: 1.6108 - val_accuracy: 0.1920
# Epoch 5/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6300 - accuracy: 0.1846 - val_loss: 1.6105 - val_accuracy: 0.1964
# Epoch 6/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.6324 - accuracy: 0.1941 - val_loss: 1.6103 - val_accuracy: 0.1875
# Epoch 7/50
# 33/33 [==============================] - 13s 406ms/step - loss: 1.6233 - accuracy: 0.2027 - val_loss: 1.6101 - val_accuracy: 0.1964
# Epoch 8/50
# 33/33 [==============================] - 13s 407ms/step - loss: 1.6197 - accuracy: 0.1960 - val_loss: 1.6101 - val_accuracy: 0.1964
# Epoch 9/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.6255 - accuracy: 0.1979 - val_loss: 1.6106 - val_accuracy: 0.2009
# Epoch 10/50
# 33/33 [==============================] - 14s 418ms/step - loss: 1.6256 - accuracy: 0.1998 - val_loss: 1.6112 - val_accuracy: 0.1920
# Epoch 11/50
# 33/33 [==============================] - 14s 429ms/step - loss: 1.6190 - accuracy: 0.2141 - val_loss: 1.6097 - val_accuracy: 0.1920
# Epoch 12/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.6209 - accuracy: 0.2131 - val_loss: 1.6100 - val_accuracy: 0.1920
# Epoch 13/50
# 33/33 [==============================] - 14s 437ms/step - loss: 1.6195 - accuracy: 0.2379 - val_loss: 1.6083 - val_accuracy: 0.2054
# Epoch 14/50
# 33/33 [==============================] - 13s 405ms/step - loss: 1.6191 - accuracy: 0.2103 - val_loss: 1.6097 - val_accuracy: 0.2098
# Epoch 15/50
# 33/33 [==============================] - 14s 435ms/step - loss: 1.6217 - accuracy: 0.2103 - val_loss: 1.6061 - val_accuracy: 0.2232
# Epoch 16/50
# 33/33 [==============================] - 14s 408ms/step - loss: 1.6196 - accuracy: 0.2150 - val_loss: 1.6126 - val_accuracy: 0.1964
# Epoch 17/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.6184 - accuracy: 0.2198 - val_loss: 1.6129 - val_accuracy: 0.2009
# Epoch 18/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6102 - accuracy: 0.2226 - val_loss: 1.6093 - val_accuracy: 0.1964
# Epoch 19/50
# 33/33 [==============================] - 13s 403ms/step - loss: 1.6230 - accuracy: 0.1941 - val_loss: 1.6070 - val_accuracy: 0.1964
# Epoch 20/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6192 - accuracy: 0.2284 - val_loss: 1.6140 - val_accuracy: 0.1920
# Epoch 21/50
# 33/33 [==============================] - 14s 413ms/step - loss: 1.6199 - accuracy: 0.2198 - val_loss: 1.6165 - val_accuracy: 0.1964
# Epoch 22/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6170 - accuracy: 0.1979 - val_loss: 1.6255 - val_accuracy: 0.2009
# Epoch 23/50
# 33/33 [==============================] - 13s 405ms/step - loss: 1.6168 - accuracy: 0.2046 - val_loss: 1.6183 - val_accuracy: 0.2009
# Epoch 24/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.6177 - accuracy: 0.2379 - val_loss: 1.6333 - val_accuracy: 0.1920
# Epoch 25/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.6140 - accuracy: 0.2265 - val_loss: 1.6103 - val_accuracy: 0.2054

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')
# Out:
# 8/8 [==============================] - 1s 79ms/step - loss: 1.6054 - accuracy: 0.2176
# Test accuracy: 0.22

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
from sklearn.metrics import roc_curve,auc
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 8/8 [==============================] - 2s 74ms/step

# %% [markdown]
# ## Metric Report Calculation for Architecture No 1

# %%
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)
y_pred_classes = np.argmax(y_pred, axis=1)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred_classes: {len(y_pred_classes)}')

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')
f2 = fbeta_score(y_true, y_pred_classes, beta=2, average='weighted')

# Print the results
print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
print(f'F2 Score: {f2:.2f}')
# Out:
# 8/8 [==============================] - 1s 70ms/step
# Length of y_true: 230
# Length of y_pred_classes: 230
# Accuracy: 0.22
# Precision: 0.05
# Recall: 0.22
# F1 Score: 0.08
# F2 Score: 0.13
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Average AUC Calculations
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred: {len(y_pred)}')

# Binarize the true labels
y_true_binarized = label_binarize(y_true, classes=range(train_generator.num_classes))

# Calculate AUC for each class
auc_scores = []
for i in range(train_generator.num_classes):
    auc = roc_auc_score(y_true_binarized[:, i], y_pred[:, i])
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)
print(f'Average AUC: {average_auc:.2f}')
# Out:
# 8/8 [==============================] - 1s 68ms/step
# Length of y_true: 230
# Length of y_pred: 230
# Average AUC: 0.49

# %% [markdown]
# # Architecture No 2

# %%
# Load the EfficientNetB2 model pretrained on ImageNet
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-2:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_2.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 33/33 [==============================] - ETA: 0s - loss: 1.7766 - accuracy: 0.2036
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 33/33 [==============================] - 24s 471ms/step - loss: 1.7766 - accuracy: 0.2036 - val_loss: 1.6128 - val_accuracy: 0.2232
# Epoch 2/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.7008 - accuracy: 0.2084 - val_loss: 1.6134 - val_accuracy: 0.1920
# Epoch 3/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6862 - accuracy: 0.1732 - val_loss: 1.6132 - val_accuracy: 0.2098
# Epoch 4/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.6466 - accuracy: 0.2017 - val_loss: 1.6146 - val_accuracy: 0.2098
# Epoch 5/50
# 33/33 [==============================] - 14s 414ms/step - loss: 1.6448 - accuracy: 0.2103 - val_loss: 1.6153 - val_accuracy: 0.2232
# Epoch 6/50
# 33/33 [==============================] - 14s 436ms/step - loss: 1.6609 - accuracy: 0.1960 - val_loss: 1.6123 - val_accuracy: 0.2232
# Epoch 7/50
# 33/33 [==============================] - 14s 420ms/step - loss: 1.6590 - accuracy: 0.2036 - val_loss: 1.6155 - val_accuracy: 0.2232
# Epoch 8/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6671 - accuracy: 0.2046 - val_loss: 1.6148 - val_accuracy: 0.2232
# Epoch 9/50
# 33/33 [==============================] - 13s 402ms/step - loss: 1.6496 - accuracy: 0.1970 - val_loss: 1.6141 - val_accuracy: 0.2232
# Epoch 10/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.6595 - accuracy: 0.1770 - val_loss: 1.6163 - val_accuracy: 0.2188
# Epoch 11/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6399 - accuracy: 0.2065 - val_loss: 1.6156 - val_accuracy: 0.2188
# Epoch 12/50
# 33/33 [==============================] - 14s 433ms/step - loss: 1.6469 - accuracy: 0.1998 - val_loss: 1.6107 - val_accuracy: 0.2143
# Epoch 13/50
# 33/33 [==============================] - 14s 408ms/step - loss: 1.6411 - accuracy: 0.2093 - val_loss: 1.6184 - val_accuracy: 0.2232
# Epoch 14/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.6330 - accuracy: 0.2084 - val_loss: 1.6219 - val_accuracy: 0.2366
# Epoch 15/50
# 33/33 [==============================] - 13s 402ms/step - loss: 1.6450 - accuracy: 0.1893 - val_loss: 1.6157 - val_accuracy: 0.2009
# Epoch 16/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.6347 - accuracy: 0.2065 - val_loss: 1.6152 - val_accuracy: 0.1964
# Epoch 17/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.6427 - accuracy: 0.2027 - val_loss: 1.6147 - val_accuracy: 0.2277
# Epoch 18/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.6328 - accuracy: 0.2055 - val_loss: 1.6297 - val_accuracy: 0.1964
# Epoch 19/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6417 - accuracy: 0.2036 - val_loss: 1.6202 - val_accuracy: 0.2232
# Epoch 20/50
# 33/33 [==============================] - 14s 408ms/step - loss: 1.6376 - accuracy: 0.2008 - val_loss: 1.6157 - val_accuracy: 0.2143
# Epoch 21/50
# 33/33 [==============================] - 14s 416ms/step - loss: 1.6311 - accuracy: 0.2103 - val_loss: 1.6221 - val_accuracy: 0.1830
# Epoch 22/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6304 - accuracy: 0.2055 - val_loss: 1.6207 - val_accuracy: 0.1830

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')
# Out:
# 8/8 [==============================] - 1s 71ms/step - loss: 1.6102 - accuracy: 0.2176
# Test accuracy: 0.22

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
from sklearn.metrics import roc_curve,auc
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 8/8 [==============================] - 2s 71ms/step

# %% [markdown]
# ## Metric Report Calculation for Architecture No 2

# %%
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)
y_pred_classes = np.argmax(y_pred, axis=1)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred_classes: {len(y_pred_classes)}')

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')
f2 = fbeta_score(y_true, y_pred_classes, beta=2, average='weighted')

# Print the results
print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
print(f'F2 Score: {f2:.2f}')
# Out:
# 8/8 [==============================] - 1s 58ms/step
# Length of y_true: 230
# Length of y_pred_classes: 230
# Accuracy: 0.22
# Precision: 0.05
# Recall: 0.22
# F1 Score: 0.08
# F2 Score: 0.13
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Average AUC Calculations
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred: {len(y_pred)}')

# Binarize the true labels
y_true_binarized = label_binarize(y_true, classes=range(train_generator.num_classes))

# Calculate AUC for each class
auc_scores = []
for i in range(train_generator.num_classes):
    auc = roc_auc_score(y_true_binarized[:, i], y_pred[:, i])
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)
print(f'Average AUC: {average_auc:.2f}')
# Out:
# 8/8 [==============================] - 1s 68ms/step
# Length of y_true: 230
# Length of y_pred: 230
# Average AUC: 0.50

# %% [markdown]
# # Architecture No 4

# %%
# Load the EfficientNetB2 model pretrained on ImageNet
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-3:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_4.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 2024-09-08 12:09:02.227273: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 33/33 [==============================] - ETA: 0s - loss: 1.8749 - accuracy: 0.2027
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 33/33 [==============================] - 25s 470ms/step - loss: 1.8749 - accuracy: 0.2027 - val_loss: 1.6097 - val_accuracy: 0.2009
# Epoch 2/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.7558 - accuracy: 0.1836 - val_loss: 1.6142 - val_accuracy: 0.1964
# Epoch 3/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.7103 - accuracy: 0.2008 - val_loss: 1.6118 - val_accuracy: 0.1875
# Epoch 4/50
# 33/33 [==============================] - 14s 420ms/step - loss: 1.7135 - accuracy: 0.2017 - val_loss: 1.6139 - val_accuracy: 0.2009
# Epoch 5/50
# 33/33 [==============================] - 13s 405ms/step - loss: 1.7528 - accuracy: 0.2046 - val_loss: 1.6106 - val_accuracy: 0.2188
# Epoch 6/50
# 33/33 [==============================] - 14s 416ms/step - loss: 1.7069 - accuracy: 0.2131 - val_loss: 1.6213 - val_accuracy: 0.1964
# Epoch 7/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.7048 - accuracy: 0.2150 - val_loss: 1.6124 - val_accuracy: 0.1964
# Epoch 8/50
# 33/33 [==============================] - 14s 428ms/step - loss: 1.7155 - accuracy: 0.2055 - val_loss: 1.6076 - val_accuracy: 0.2188
# Epoch 9/50
# 33/33 [==============================] - 13s 406ms/step - loss: 1.7062 - accuracy: 0.2093 - val_loss: 1.6139 - val_accuracy: 0.2232
# Epoch 10/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.7016 - accuracy: 0.2055 - val_loss: 1.6165 - val_accuracy: 0.2188
# Epoch 11/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6925 - accuracy: 0.2169 - val_loss: 1.6147 - val_accuracy: 0.2009
# Epoch 12/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.6780 - accuracy: 0.1970 - val_loss: 1.6081 - val_accuracy: 0.2411
# Epoch 13/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.7136 - accuracy: 0.1979 - val_loss: 1.6115 - val_accuracy: 0.2143
# Epoch 14/50
# 33/33 [==============================] - 13s 403ms/step - loss: 1.6985 - accuracy: 0.2093 - val_loss: 1.6111 - val_accuracy: 0.2143
# Epoch 15/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.7079 - accuracy: 0.2217 - val_loss: 1.6387 - val_accuracy: 0.1964
# Epoch 16/50
# 33/33 [==============================] - 14s 415ms/step - loss: 1.6840 - accuracy: 0.2141 - val_loss: 1.6133 - val_accuracy: 0.1875
# Epoch 17/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6712 - accuracy: 0.2093 - val_loss: 1.6204 - val_accuracy: 0.1964
# Epoch 18/50
# 33/33 [==============================] - 14s 415ms/step - loss: 1.6831 - accuracy: 0.2036 - val_loss: 1.6287 - val_accuracy: 0.1964

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')
# Out:
# 8/8 [==============================] - 1s 68ms/step - loss: 1.6074 - accuracy: 0.2176
# Test accuracy: 0.22

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
# Out:
# 8/8 [==============================] - 2s 68ms/step

# %% [markdown]
# ## Metric Report Calculation for Architecture No 4

# %%
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)
y_pred_classes = np.argmax(y_pred, axis=1)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred_classes: {len(y_pred_classes)}')

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')
f2 = fbeta_score(y_true, y_pred_classes, beta=2, average='weighted')

# Print the results
print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
print(f'F2 Score: {f2:.2f}')
# Out:
# 8/8 [==============================] - 1s 67ms/step
# Length of y_true: 230
# Length of y_pred_classes: 230
# Accuracy: 0.22
# Precision: 0.05
# Recall: 0.22
# F1 Score: 0.08
# F2 Score: 0.13
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Average AUC Calculations
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred: {len(y_pred)}')

# Binarize the true labels
y_true_binarized = label_binarize(y_true, classes=range(train_generator.num_classes))

# Calculate AUC for each class
auc_scores = []
for i in range(train_generator.num_classes):
    auc = roc_auc_score(y_true_binarized[:, i], y_pred[:, i])
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)
print(f'Average AUC: {average_auc:.2f}')
# Out:
# 8/8 [==============================] - 1s 69ms/step
# Length of y_true: 230
# Length of y_pred: 230
# Average AUC: 0.51

# %% [markdown]
# # Architecture No 5

# %%
# Load the EfficienNetB2 model pretrained on ImageNet
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-4:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_5.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 2024-09-08 12:13:27.475878: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_3/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 33/33 [==============================] - ETA: 0s - loss: 1.8204 - accuracy: 0.2017
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 33/33 [==============================] - 25s 474ms/step - loss: 1.8204 - accuracy: 0.2017 - val_loss: 1.6108 - val_accuracy: 0.2009
# Epoch 2/50
# 33/33 [==============================] - 14s 415ms/step - loss: 1.7790 - accuracy: 0.1970 - val_loss: 1.6132 - val_accuracy: 0.1920
# Epoch 3/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.8051 - accuracy: 0.2084 - val_loss: 1.6133 - val_accuracy: 0.1964
# Epoch 4/50
# 33/33 [==============================] - 15s 440ms/step - loss: 1.7604 - accuracy: 0.2131 - val_loss: 1.6096 - val_accuracy: 0.2232
# Epoch 5/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.7234 - accuracy: 0.2008 - val_loss: 1.6130 - val_accuracy: 0.2188
# Epoch 6/50
# 33/33 [==============================] - 14s 424ms/step - loss: 1.7363 - accuracy: 0.1893 - val_loss: 1.6071 - val_accuracy: 0.2232
# Epoch 7/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.7070 - accuracy: 0.2084 - val_loss: 1.6153 - val_accuracy: 0.2188
# Epoch 8/50
# 33/33 [==============================] - 13s 405ms/step - loss: 1.6991 - accuracy: 0.2103 - val_loss: 1.6193 - val_accuracy: 0.1964
# Epoch 9/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.7326 - accuracy: 0.2046 - val_loss: 1.6322 - val_accuracy: 0.1875
# Epoch 10/50
# 33/33 [==============================] - 13s 405ms/step - loss: 1.7304 - accuracy: 0.1989 - val_loss: 1.6161 - val_accuracy: 0.1964
# Epoch 11/50
# 33/33 [==============================] - 14s 408ms/step - loss: 1.7012 - accuracy: 0.1998 - val_loss: 1.6076 - val_accuracy: 0.2232
# Epoch 12/50
# 33/33 [==============================] - 13s 403ms/step - loss: 1.7162 - accuracy: 0.2093 - val_loss: 1.6186 - val_accuracy: 0.1964
# Epoch 13/50
# 33/33 [==============================] - 14s 408ms/step - loss: 1.7121 - accuracy: 0.2093 - val_loss: 1.6137 - val_accuracy: 0.1920
# Epoch 14/50
# 33/33 [==============================] - 13s 402ms/step - loss: 1.6964 - accuracy: 0.2160 - val_loss: 1.6226 - val_accuracy: 0.1920
# Epoch 15/50
# 33/33 [==============================] - 13s 407ms/step - loss: 1.7160 - accuracy: 0.1865 - val_loss: 1.6303 - val_accuracy: 0.1875
# Epoch 16/50
# 33/33 [==============================] - 14s 413ms/step - loss: 1.6897 - accuracy: 0.2160 - val_loss: 1.6496 - val_accuracy: 0.2009

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')
# Out:
# 8/8 [==============================] - 1s 72ms/step - loss: 1.6079 - accuracy: 0.2176
# Test accuracy: 0.22

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 8/8 [==============================] - 2s 67ms/step

# %% [markdown]
# ## Metric Report Calculation for Architecture No 5

# %%
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)
y_pred_classes = np.argmax(y_pred, axis=1)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred_classes: {len(y_pred_classes)}')

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')
f2 = fbeta_score(y_true, y_pred_classes, beta=2, average='weighted')

# Print the results
print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
print(f'F2 Score: {f2:.2f}')
# Out:
# 8/8 [==============================] - 1s 78ms/step
# Length of y_true: 230
# Length of y_pred_classes: 230
# Accuracy: 0.22
# Precision: 0.05
# Recall: 0.22
# F1 Score: 0.08
# F2 Score: 0.13
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Average AUC Calculations
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred: {len(y_pred)}')

# Binarize the true labels
y_true_binarized = label_binarize(y_true, classes=range(train_generator.num_classes))

# Calculate AUC for each class
auc_scores = []
for i in range(train_generator.num_classes):
    auc = roc_auc_score(y_true_binarized[:, i], y_pred[:, i])
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)
print(f'Average AUC: {average_auc:.2f}')
# Out:
# 8/8 [==============================] - 1s 81ms/step
# Length of y_true: 230
# Length of y_pred: 230
# Average AUC: 0.50

# %% [markdown]
# # Architecture No 6

# %%
# Load the EfficientNetB2 model pretrained on ImageNet
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-4:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_512')(top_model)
top_model = Dropout(0.3)(top_model)
top_model = Dense(64, activation='relu', name = 'Dense_64')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_6.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 2024-09-08 12:17:25.050858: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_4/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 33/33 [==============================] - ETA: 0s - loss: 1.7698 - accuracy: 0.2084
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 33/33 [==============================] - 25s 486ms/step - loss: 1.7698 - accuracy: 0.2084 - val_loss: 1.6164 - val_accuracy: 0.1964
# Epoch 2/50
# 33/33 [==============================] - 14s 429ms/step - loss: 1.7375 - accuracy: 0.1903 - val_loss: 1.6134 - val_accuracy: 0.1964
# Epoch 3/50
# 33/33 [==============================] - 14s 425ms/step - loss: 1.7004 - accuracy: 0.2008 - val_loss: 1.6112 - val_accuracy: 0.1964
# Epoch 4/50
# 33/33 [==============================] - 14s 428ms/step - loss: 1.7142 - accuracy: 0.1703 - val_loss: 1.6110 - val_accuracy: 0.1964
# Epoch 5/50
# 33/33 [==============================] - 14s 429ms/step - loss: 1.6910 - accuracy: 0.1912 - val_loss: 1.6099 - val_accuracy: 0.2143
# Epoch 6/50
# 33/33 [==============================] - 14s 418ms/step - loss: 1.6649 - accuracy: 0.2027 - val_loss: 1.6087 - val_accuracy: 0.2009
# Epoch 7/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.6694 - accuracy: 0.2074 - val_loss: 1.6095 - val_accuracy: 0.2009
# Epoch 8/50
# 33/33 [==============================] - 14s 413ms/step - loss: 1.6724 - accuracy: 0.1874 - val_loss: 1.6092 - val_accuracy: 0.2232
# Epoch 9/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6577 - accuracy: 0.1922 - val_loss: 1.6101 - val_accuracy: 0.2098
# Epoch 10/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.6485 - accuracy: 0.2055 - val_loss: 1.6097 - val_accuracy: 0.2188
# Epoch 11/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6562 - accuracy: 0.1893 - val_loss: 1.6102 - val_accuracy: 0.1652
# Epoch 12/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.6404 - accuracy: 0.2065 - val_loss: 1.6094 - val_accuracy: 0.1830
# Epoch 13/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6241 - accuracy: 0.2284 - val_loss: 1.6103 - val_accuracy: 0.1964
# Epoch 14/50
# 33/33 [==============================] - 14s 408ms/step - loss: 1.6394 - accuracy: 0.1893 - val_loss: 1.6158 - val_accuracy: 0.1964
# Epoch 15/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.6343 - accuracy: 0.2074 - val_loss: 1.6120 - val_accuracy: 0.1964
# Epoch 16/50
# 33/33 [==============================] - 14s 430ms/step - loss: 1.6243 - accuracy: 0.2017 - val_loss: 1.6083 - val_accuracy: 0.1964
# Epoch 17/50
# 33/33 [==============================] - 13s 401ms/step - loss: 1.6334 - accuracy: 0.2027 - val_loss: 1.6089 - val_accuracy: 0.2009
# Epoch 18/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.6268 - accuracy: 0.1960 - val_loss: 1.6096 - val_accuracy: 0.1964
# Epoch 19/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6257 - accuracy: 0.2188 - val_loss: 1.6122 - val_accuracy: 0.1920
# Epoch 20/50
# 33/33 [==============================] - 14s 437ms/step - loss: 1.6328 - accuracy: 0.2112 - val_loss: 1.6063 - val_accuracy: 0.2277
# Epoch 21/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.6307 - accuracy: 0.1912 - val_loss: 1.6084 - val_accuracy: 0.2188
# Epoch 22/50
# 33/33 [==============================] - 13s 402ms/step - loss: 1.6346 - accuracy: 0.1922 - val_loss: 1.6084 - val_accuracy: 0.2188
# Epoch 23/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.6252 - accuracy: 0.2084 - val_loss: 1.6074 - val_accuracy: 0.1696
# Epoch 24/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.6171 - accuracy: 0.1951 - val_loss: 1.6105 - val_accuracy: 0.2098
# Epoch 25/50
# 33/33 [==============================] - 14s 416ms/step - loss: 1.6201 - accuracy: 0.2150 - val_loss: 1.6120 - val_accuracy: 0.2232
# Epoch 26/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.6271 - accuracy: 0.2131 - val_loss: 1.6093 - val_accuracy: 0.2232
# Epoch 27/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6208 - accuracy: 0.2265 - val_loss: 1.6083 - val_accuracy: 0.2232
# Epoch 28/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6199 - accuracy: 0.1941 - val_loss: 1.6080 - val_accuracy: 0.1786
# Epoch 29/50
# 33/33 [==============================] - 13s 407ms/step - loss: 1.6159 - accuracy: 0.2150 - val_loss: 1.6093 - val_accuracy: 0.2009
# Epoch 30/50
# 33/33 [==============================] - 14s 413ms/step - loss: 1.6311 - accuracy: 0.1922 - val_loss: 1.6100 - val_accuracy: 0.1920

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')
# Out:
# 8/8 [==============================] - 1s 75ms/step - loss: 1.6047 - accuracy: 0.2092
# Test accuracy: 0.21

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 8/8 [==============================] - 2s 75ms/step

# %% [markdown]
# ## Metric Report Calculation fro Architecture No 6

# %%
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)
y_pred_classes = np.argmax(y_pred, axis=1)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred_classes: {len(y_pred_classes)}')

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')
f2 = fbeta_score(y_true, y_pred_classes, beta=2, average='weighted')

# Print the results
print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
print(f'F2 Score: {f2:.2f}')
# Out:
# 8/8 [==============================] - 1s 75ms/step
# Length of y_true: 230
# Length of y_pred_classes: 230
# Accuracy: 0.18
# Precision: 0.09
# Recall: 0.18
# F1 Score: 0.09
# F2 Score: 0.12
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Average AUC Calculations
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred: {len(y_pred)}')

# Binarize the true labels
y_true_binarized = label_binarize(y_true, classes=range(train_generator.num_classes))

# Calculate AUC for each class
auc_scores = []
for i in range(train_generator.num_classes):
    auc = roc_auc_score(y_true_binarized[:, i], y_pred[:, i])
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)
print(f'Average AUC: {average_auc:.2f}')
# Out:
# 8/8 [==============================] - 1s 68ms/step
# Length of y_true: 230
# Length of y_pred: 230
# Average AUC: 0.45

# %% [markdown]
# # Architecture No 7

# %%
# Load the EfficientNetB2 model pretrained on ImageNet
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the convolutional base
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze the last few layers of the base model
for layer in base_model.layers[-4:]:  # Change the number of layers to unfreeze as needed
    layer.trainable = True

top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(2048, activation= 'relu', name = 'Dense_1024')(top_model)
top_model = BatchNormalization()(top_model)
top_model = Dense(1024, activation='relu', name = 'Dense_512')(top_model)
top_model = Dropout(0.3)(top_model)
top_model = Dense(512, activation='relu', name = 'Dense_64')(top_model)
predictions = Dense(num_classes, activation = 'softmax', name= 'Output_layer')(top_model)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('Architecture_no_7.h5', monitor='val_loss', save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 2024-09-08 12:24:37.545261: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_5/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 33/33 [==============================] - ETA: 0s - loss: 1.8919 - accuracy: 0.2008
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 33/33 [==============================] - 25s 489ms/step - loss: 1.8919 - accuracy: 0.2008 - val_loss: 1.6141 - val_accuracy: 0.2009
# Epoch 2/50
# 33/33 [==============================] - 14s 406ms/step - loss: 1.7894 - accuracy: 0.2265 - val_loss: 1.6191 - val_accuracy: 0.1875
# Epoch 3/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.7802 - accuracy: 0.2093 - val_loss: 1.6222 - val_accuracy: 0.2009
# Epoch 4/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.7055 - accuracy: 0.2198 - val_loss: 1.6160 - val_accuracy: 0.1920
# Epoch 5/50
# 33/33 [==============================] - 14s 423ms/step - loss: 1.7700 - accuracy: 0.1874 - val_loss: 1.6110 - val_accuracy: 0.1964
# Epoch 6/50
# 33/33 [==============================] - 14s 430ms/step - loss: 1.7423 - accuracy: 0.2188 - val_loss: 1.6102 - val_accuracy: 0.1964
# Epoch 7/50
# 33/33 [==============================] - 14s 438ms/step - loss: 1.7191 - accuracy: 0.2169 - val_loss: 1.6083 - val_accuracy: 0.2277
# Epoch 8/50
# 33/33 [==============================] - 14s 412ms/step - loss: 1.7017 - accuracy: 0.2141 - val_loss: 1.6166 - val_accuracy: 0.1964
# Epoch 9/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.7111 - accuracy: 0.2236 - val_loss: 1.6096 - val_accuracy: 0.1920
# Epoch 10/50
# 33/33 [==============================] - 14s 411ms/step - loss: 1.6922 - accuracy: 0.2084 - val_loss: 1.6120 - val_accuracy: 0.1964
# Epoch 11/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.7318 - accuracy: 0.1855 - val_loss: 1.6096 - val_accuracy: 0.2232
# Epoch 12/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.6978 - accuracy: 0.1979 - val_loss: 1.6101 - val_accuracy: 0.2723
# Epoch 13/50
# 33/33 [==============================] - 14s 432ms/step - loss: 1.7067 - accuracy: 0.1951 - val_loss: 1.6058 - val_accuracy: 0.2143
# Epoch 14/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.6831 - accuracy: 0.2008 - val_loss: 1.6106 - val_accuracy: 0.2009
# Epoch 15/50
# 33/33 [==============================] - 14s 410ms/step - loss: 1.7006 - accuracy: 0.2008 - val_loss: 1.6070 - val_accuracy: 0.2277
# Epoch 16/50
# 33/33 [==============================] - 14s 407ms/step - loss: 1.6820 - accuracy: 0.2074 - val_loss: 1.6082 - val_accuracy: 0.2455
# Epoch 17/50
# 33/33 [==============================] - 13s 406ms/step - loss: 1.6796 - accuracy: 0.2055 - val_loss: 1.6136 - val_accuracy: 0.2188
# Epoch 18/50
# 33/33 [==============================] - 14s 409ms/step - loss: 1.6720 - accuracy: 0.2207 - val_loss: 1.6140 - val_accuracy: 0.1964
# Epoch 19/50
# 33/33 [==============================] - 13s 405ms/step - loss: 1.6722 - accuracy: 0.2027 - val_loss: 1.6139 - val_accuracy: 0.2009
# Epoch 20/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.6749 - accuracy: 0.2112 - val_loss: 1.6083 - val_accuracy: 0.2009
# Epoch 21/50
# 33/33 [==============================] - 14s 417ms/step - loss: 1.6734 - accuracy: 0.2103 - val_loss: 1.6245 - val_accuracy: 0.1920
# Epoch 22/50
# 33/33 [==============================] - 14s 416ms/step - loss: 1.6645 - accuracy: 0.2065 - val_loss: 1.6075 - val_accuracy: 0.2143
# Epoch 23/50
# 33/33 [==============================] - 14s 416ms/step - loss: 1.6562 - accuracy: 0.1951 - val_loss: 1.6108 - val_accuracy: 0.2188

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy:.2f}')
# Out:
# 8/8 [==============================] - 1s 65ms/step - loss: 1.6056 - accuracy: 0.2134
# Test accuracy: 0.21

# %%
epochs = [i for i in range(len(history.epoch))]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc, 'go-', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label = 'Validation Accuracy')
ax[0].set_title('Training and validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label = 'Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label = 'Validation Loss')
ax[1].set_title('Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
# Predict probabilities for the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_true = tf.keras.utils.to_categorical(y_true, num_classes=num_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {i}) (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 8/8 [==============================] - 2s 78ms/step

# %% [markdown]
# ## Metric Report Calculation for Architecture No 7

# %%
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)
y_pred_classes = np.argmax(y_pred, axis=1)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred_classes: {len(y_pred_classes)}')

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')
f2 = fbeta_score(y_true, y_pred_classes, beta=2, average='weighted')

# Print the results
print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
print(f'F2 Score: {f2:.2f}')
# Out:
# 8/8 [==============================] - 1s 71ms/step
# Length of y_true: 230
# Length of y_pred_classes: 230
# Accuracy: 0.19
# Precision: 0.08
# Recall: 0.19
# F1 Score: 0.11
# F2 Score: 0.14
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Average AUC Calculations
# Make predictions
val_steps = np.ceil(validation_generator.samples / validation_generator.batch_size)
y_pred = model.predict(validation_generator, steps=val_steps)

# Ensure lengths match
y_true = validation_generator.classes
print(f'Length of y_true: {len(y_true)}')
print(f'Length of y_pred: {len(y_pred)}')

# Binarize the true labels
y_true_binarized = label_binarize(y_true, classes=range(train_generator.num_classes))

# Calculate AUC for each class
auc_scores = []
for i in range(train_generator.num_classes):
    auc = roc_auc_score(y_true_binarized[:, i], y_pred[:, i])
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)
print(f'Average AUC: {average_auc:.2f}')
# Out:
# 8/8 [==============================] - 1s 79ms/step
# Length of y_true: 230
# Length of y_pred: 230
# Average AUC: 0.52
